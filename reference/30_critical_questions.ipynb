# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vkoul/ab-test-practice/blob/main/reference/30_critical_questions.ipynb)
#
# > **Run this notebook interactively:** Click the badge above to open in Google Colab.

# %% [markdown]
# # 30 Critical Questions: A/B Testing in Practice
#
# Test your understanding of the full course. Try to answer each question WITHOUT looking at your notes first, then check yourself.
#
# **Scoring guide:**
# - Answer from memory first
# - Then check against your notes/solutions
# - Mark: ✅ (knew it), ⚠️ (partially right), ❌ (didn't know)
# - Target: 25+ correct = ready to apply in practice
#
# **Format:** Each question has a markdown cell for the question followed by a markdown cell placeholder for your answer.

# %% [markdown]
# ---
# ## Metric Selection & Test Design (Questions 1-7)

# %% [markdown]
# ### Q1.
#
# **Your team is optimizing the onboarding flow at FamilyNest. You're choosing between NAL (2-hour lag, 40% baseline), NBL (7-day lag, 20% baseline), and NRL (23-day lag, 10.8% baseline) as the target metric. Which do you pick and why? What are the specific trade-offs you're making?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q2.
#
# **You chose NBL as your target metric. Your PM asks "why not just use revenue?" Give three specific reasons why revenue might be a poor A/B test metric for onboarding changes.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q3.
#
# **Calculate the required sample size for: baseline rate = 20%, MDE = 5% relative lift (1 percentage point absolute), alpha = 0.05, power = 0.80. Show your work with the formula. Then calculate the test duration if you have 5,000 users/day.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q4.
#
# **You have only 500 users per day entering the flow. You want to detect a 5% relative lift on NBL (baseline 20%). How many days would you need? Is this practical? What are your options to make it feasible?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q5.
#
# **What is the difference between a guardrail metric and an informative metric? Give an example of each for an onboarding test where NBL is the target.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q6.
#
# **Write a proper hypothesis for this test: "We want to test adding a progress bar to the onboarding flow." Include the mechanism (the WHY).**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q7.
#
# **Your test requires 28 days to reach adequate power. Your PM asks if you can run it for 21 days instead. What exactly are the statistical consequences of this? Be specific about what happens to power and MDE.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ---
# ## Validity Threats (Questions 8-14)

# %% [markdown]
# ### Q8.
#
# **You run a chi-squared test on your variant assignment and get p = 0.03. What does this mean? What should you do next? Can you still use the test results?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q9.
#
# **A test targeting only African users has data from 103,505 users across ALL continents. Only 15,000 are from Africa. What went wrong? How do you proceed with the analysis?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q10.
#
# **You break down your test results by continent and find: the treatment helps in North America (+8%, p=0.01) but hurts in Europe (-4%, p=0.04). The overall result is +3% (p=0.03). Should you launch? What's your recommendation and why?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q11.
#
# **Your A/B test is on the onboarding page. A host in the treatment group tells their friend "the sign-up was so easy!" and the friend signs up. That friend happens to be randomized into the control group. What assumption has been violated? Does this bias your results upward or downward?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q12.
#
# **You notice that 98% of users in the treatment group are on iOS, while the control group is 50/50 iOS/Android. Assignment imbalance overall is fine (50/50 treatment/control). What's going on? Can you trust the results?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q13.
#
# **Explain why "intent to treat" analysis is preferred in A/B testing. When might "as treated" analysis be appropriate?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q14.
#
# **Your test ran for 4 weeks. When you break down by week, Week 1 shows +10%, Week 2 shows +5%, Week 3 shows +3%, Week 4 shows +2%. The overall result is +4%. Should you launch? What pattern does this suggest?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ---
# ## Early Results & Stakeholder Management (Questions 15-21)

# %% [markdown]
# ### Q15.
#
# **Your test is planned for 28 days. On day 7, the p-value is 0.02 and the lift is +12%. Your PM says "that's clearly significant, let's ship!" Give three specific, quantitative reasons why you should NOT ship now.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q16.
#
# **Explain the "winner's curse" in the context of A/B testing. Why are early significant results likely to overestimate the true effect?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q17.
#
# **You're monitoring a test and the guardrail metric (NCL) shows a +25% increase in cancellations after 5 days, with p = 0.001. The test was planned for 28 days. What do you do?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q18.
#
# **Write a 3-sentence email to your PM explaining why you can't ship based on early positive results. Be professional and constructive, not dismissive.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q19.
#
# **You plot the relative lift over time (by cohort hour) and see: Hour 1-5: +15%, Hour 6-20: +8%, Hour 20-48: +5%, Hour 48-72: +5%. Is there a novelty effect? Has it stabilized? What do you conclude?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q20.
#
# **A test completes its full run. Target metric shows +2% relative lift, p = 0.08, 95% CI = [-0.3%, +4.3%]. Your PM says "it's close to significant, can we call it a win?" What's your response? Be specific about what the CI tells you.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q21.
#
# **You peeked at results 5 times during a 4-week test. Each time, p > 0.05. On the final day, p = 0.04. Can you trust this result? What's the actual false positive rate after 5 peeks?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ---
# ## Concurrent Tests (Questions 22-27)

# %% [markdown]
# ### Q22.
#
# **You have two changes for the same page: (A) a pricing algorithm and (B) a discount checkbox. With 4,000 users/day, compare the timeline for: (i) sequential testing, (ii) mutual exclusion, (iii) overlapping tests. Assume each test needs ~60,000 total users.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q23.
#
# **You ran overlapping tests. Test A shows +3% lift (p=0.02). Test B shows +2% lift (p=0.04). You merge the datasets and check: effect of A when B is absent = +4%, effect of A when B is present = +1%. What does this tell you? Should you ship both?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q24.
#
# **Explain why Bonferroni correction is needed in a multi-arm test. If you have 3 treatment variants (plus control), and you test each against control at alpha = 0.05, what's your actual family-wise error rate without correction?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q25.
#
# **In a full factorial design (control, A-only, B-only, A+B), the results are: Control: 20%, A-only: 21%, B-only: 21.5%, A+B: 24%. Is there a positive interaction, negative interaction, or no interaction? Show your reasoning.**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q26.
#
# **Your team has 3 ideas to test on the same page. One engineer says "just run them all overlapping." Another says "let's do a full factorial with 8 cells." You have 2,000 users/day. What do you recommend and why?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q27.
#
# **After detecting a negative interaction between two features, your PM says "just ship both together since A+B still beats control." Is this always a valid strategy? What are the risks?**

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ---
# ## Synthesis & Applied Thinking (Questions 28-30)

# %% [markdown]
# ### Q28.
#
# **Design a complete A/B test from scratch:** You want to test replacing the text-based listing description with a structured template (checkboxes + dropdowns) at FamilyNest.
#
# Define:
# - Target metric
# - Guardrail metric(s)
# - Hypothesis (with mechanism)
# - Sample size calculation (assume baseline 20% NBL, 3,000 users/day, want to detect 8% relative lift)
# - Duration
# - Launch criteria

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q29.
#
# **You join a new company. A colleague shows you test results: "We got a +15% lift in sign-ups! p = 0.001!" You ask five questions before deciding if you trust it. What are they?** (Think about everything you've learned across all 4 weeks.)

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ### Q30.
#
# **Rank these five scenarios from "most trustworthy result" to "least trustworthy" and explain why:**
#
# - **(A)** Full-duration test, p=0.03, no validity issues, 5% lift
# - **(B)** Early-stopped test (day 7 of 28), p=0.001, +15% lift
# - **(C)** Full-duration test, p=0.04, assignment imbalance detected (p=0.03 on chi-sq)
# - **(D)** Full-duration test, p=0.02, but only significant in one segment (North America)
# - **(E)** Full-duration test, p=0.08, CI = [-0.5%, +5.5%], no validity issues

# %% [markdown]
# **Your answer:**
#
# [Write your answer here]
#
# ---
# *Self-assessment:* ✅ / ⚠️ / ❌

# %% [markdown]
# ---
# ## Score Summary
#
# | Category | Questions | Score |
# |----------|-----------|-------|
# | Metric Selection & Design | Q1-Q7 | /7 |
# | Validity Threats | Q8-Q14 | /7 |
# | Early Results & Stakeholders | Q15-Q21 | /7 |
# | Concurrent Tests | Q22-Q27 | /6 |
# | Synthesis & Applied | Q28-Q30 | /3 |
# | **TOTAL** | | **/30** |
#
# ### Interpretation
# - 25-30: Ready to run A/B tests independently
# - 20-24: Solid foundation, review weak areas
# - 15-19: Re-read study notes before attempting assignments
# - Below 15: Start from Week 1 study notes again
